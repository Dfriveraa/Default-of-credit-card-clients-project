# %%
import joblib
import pandas as pd

# %%
result=joblib.load('gs_rna.pkl')

# %%
resultado=pd.DataFrame(result.cv_results_)

# %%
resultado.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_activation', 'param_alpha', 'param_hidden_layer_sizes',
#        'param_max_iter', 'param_solver', 'params', 'split0_test_AUC',
#        'split1_test_AUC', 'mean_test_AUC', 'std_test_AUC', 'rank_test_AUC',
#        'split0_train_AUC', 'split1_train_AUC', 'mean_train_AUC',
#        'std_train_AUC', 'split0_test_Accuracy', 'split1_test_Accuracy',
#        'mean_test_Accuracy', 'std_test_Accuracy', 'rank_test_Accuracy',
#        'split0_train_Accuracy', 'split1_train_Accuracy', 'mean_train_Accuracy',
#        'std_train_Accuracy'],
#       dtype='object')

# %%
resultado[['params','mean_test_AUC','std_test_AUC','mean_test_Accuracy','std_test_Accuracy']].sort_values(['mean_test_AUC'], ascending=[False])
# Out:
#                                                params  mean_test_AUC  \
# 36  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.775730
# 27  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.774496
# 46  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.773317
# 39  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.772879
# 41  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.772843
# 30  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.772262
# 38  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.772103
# 49  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.772038
# 48  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.772038
# 35  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.771525
# 52  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.771248
# 45  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.771143
# 37  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.771018
# 43  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.770448
# 18  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.770356
# 51  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.770251
# 53  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.770183
# 26  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.769955
# 34  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.769521
# 22  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.769407
# 42  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.769367
# 29  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.769108
# 50  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.769084
# 24  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.768686
# 13  {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.768477
# 19  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.768217
# 9   {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.768204
# 12  {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.768189
# 20  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.768122
# 21  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.768099
# 23  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.767949
# 0   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.767901
# 11  {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.767865
# 31  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.767830
# 10  {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.767549
# 40  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.767527
# 44  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.767351
# 15  {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.767345
# 17  {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.767266
# 25  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.767109
# 5   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.767051
# 2   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.766859
# 1   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.766653
# 14  {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.766572
# 4   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.766165
# 3   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.766028
# 33  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.766017
# 16  {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.765973
# 6   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.765089
# 8   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.764894
# 32  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.764737
# 47  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.764143
# 7   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.764019
# 28  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.763869
#
#     std_test_AUC  mean_test_Accuracy  std_test_Accuracy
# 36      0.003400            0.819417           0.003000
# 27      0.004643            0.819958           0.004875
# 46      0.004406            0.820125           0.005625
# 39      0.005629            0.821000           0.003167
# 41      0.007035            0.818708           0.004458
# 30      0.004685            0.821625           0.001542
# 38      0.004209            0.820458           0.004708
# 49      0.001450            0.820250           0.004917
# 48      0.003249            0.820875           0.002708
# 35      0.003073            0.819500           0.004333
# 52      0.004498            0.819750           0.003917
# 45      0.002585            0.819833           0.002583
# 37      0.002790            0.819625           0.004292
# 43      0.006938            0.819000           0.003000
# 18      0.004072            0.819583           0.003917
# 51      0.006132            0.821792           0.003375
# 53      0.000222            0.820583           0.002750
# 26      0.003881            0.820917           0.003583
# 34      0.006286            0.819500           0.005500
# 22      0.002955            0.820042           0.004542
# 42      0.001492            0.823083           0.001750
# 29      0.002656            0.820000           0.004417
# 50      0.003278            0.820625           0.002792
# 24      0.002283            0.819917           0.004250
# 13      0.002965            0.820667           0.003417
# 19      0.001211            0.819000           0.003583
# 9       0.000796            0.820708           0.004208
# 12      0.002446            0.819958           0.002875
# 20      0.001456            0.818083           0.002167
# 21      0.001920            0.821167           0.004083
# 23      0.002128            0.819750           0.003833
# 0       0.002447            0.819542           0.004125
# 11      0.001198            0.818667           0.002583
# 31      0.000504            0.820792           0.003375
# 10      0.002273            0.819583           0.003833
# 40      0.004290            0.822208           0.001708
# 44      0.005410            0.820208           0.004208
# 15      0.002347            0.819875           0.004125
# 17      0.001775            0.820292           0.003375
# 25      0.002848            0.818500           0.000333
# 5       0.002448            0.819417           0.005333
# 2       0.000903            0.819750           0.003750
# 1       0.001516            0.817542           0.002042
# 14      0.001296            0.815042           0.000708
# 4       0.002242            0.819208           0.003458
# 3       0.001832            0.818167           0.003333
# 33      0.004651            0.820042           0.002042
# 16      0.001191            0.818458           0.003792
# 6       0.001751            0.820167           0.003667
# 8       0.001090            0.819583           0.004583
# 32      0.010438            0.818000           0.005083
# 47      0.004052            0.819417           0.002083
# 7       0.003408            0.814250           0.008750
# 28      0.003583            0.819417           0.002250
