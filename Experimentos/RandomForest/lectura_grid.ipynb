# %%
import joblib
import pandas as pd

# %%
result=joblib.load('gs_rf.pkl')

# %%
resultado=pd.DataFrame(result.cv_results_)

# %%
resultado.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_criterion', 'param_max_features', 'param_n_estimators', 'params',
#        'split0_test_AUC', 'split1_test_AUC', 'split2_test_AUC',
#        'mean_test_AUC', 'std_test_AUC', 'rank_test_AUC', 'split0_train_AUC',
#        'split1_train_AUC', 'split2_train_AUC', 'mean_train_AUC',
#        'std_train_AUC', 'split0_test_Accuracy', 'split1_test_Accuracy',
#        'split2_test_Accuracy', 'mean_test_Accuracy', 'std_test_Accuracy',
#        'rank_test_Accuracy', 'split0_train_Accuracy', 'split1_train_Accuracy',
#        'split2_train_Accuracy', 'mean_train_Accuracy', 'std_train_Accuracy'],
#       dtype='object')

# %%
resultado[['params','mean_test_AUC','std_test_AUC','mean_test_Accuracy','std_test_Accuracy']].sort_values(['mean_test_AUC'], ascending=[False])
# Out:
#                                                params  mean_test_AUC  \
# 34  {'criterion': 'entropy', 'max_features': 4, 'n...       0.770496
# 5   {'criterion': 'gini', 'max_features': 4, 'n_es...       0.769598
# 55  {'criterion': 'entropy', 'max_features': 'auto...       0.769028
# 54  {'criterion': 'entropy', 'max_features': 'auto...       0.768878
# 27  {'criterion': 'gini', 'max_features': 'auto', ...       0.768798
# 33  {'criterion': 'entropy', 'max_features': 4, 'n...       0.768634
# 6   {'criterion': 'gini', 'max_features': 4, 'n_es...       0.768210
# 26  {'criterion': 'gini', 'max_features': 'auto', ...       0.767867
# 40  {'criterion': 'entropy', 'max_features': 8, 'n...       0.767066
# 53  {'criterion': 'entropy', 'max_features': 'auto...       0.766709
# 41  {'criterion': 'entropy', 'max_features': 8, 'n...       0.766567
# 48  {'criterion': 'entropy', 'max_features': 12, '...       0.766094
# 32  {'criterion': 'entropy', 'max_features': 4, 'n...       0.765970
# 47  {'criterion': 'entropy', 'max_features': 12, '...       0.765877
# 12  {'criterion': 'gini', 'max_features': 8, 'n_es...       0.765816
# 4   {'criterion': 'gini', 'max_features': 4, 'n_es...       0.765142
# 13  {'criterion': 'gini', 'max_features': 8, 'n_es...       0.765077
# 20  {'criterion': 'gini', 'max_features': 12, 'n_e...       0.763497
# 31  {'criterion': 'entropy', 'max_features': 4, 'n...       0.763355
# 25  {'criterion': 'gini', 'max_features': 'auto', ...       0.762932
# 19  {'criterion': 'gini', 'max_features': 12, 'n_e...       0.762854
# 39  {'criterion': 'entropy', 'max_features': 8, 'n...       0.762294
# 11  {'criterion': 'gini', 'max_features': 8, 'n_es...       0.762026
# 46  {'criterion': 'entropy', 'max_features': 12, '...       0.761906
# 52  {'criterion': 'entropy', 'max_features': 'auto...       0.761199
# 24  {'criterion': 'gini', 'max_features': 'auto', ...       0.760763
# 3   {'criterion': 'gini', 'max_features': 4, 'n_es...       0.759832
# 38  {'criterion': 'entropy', 'max_features': 8, 'n...       0.759537
# 18  {'criterion': 'gini', 'max_features': 12, 'n_e...       0.759478
# 45  {'criterion': 'entropy', 'max_features': 12, '...       0.757793
# 10  {'criterion': 'gini', 'max_features': 8, 'n_es...       0.756389
# 17  {'criterion': 'gini', 'max_features': 12, 'n_e...       0.755465
# 30  {'criterion': 'entropy', 'max_features': 4, 'n...       0.749398
# 2   {'criterion': 'gini', 'max_features': 4, 'n_es...       0.748843
# 44  {'criterion': 'entropy', 'max_features': 12, '...       0.748272
# 23  {'criterion': 'gini', 'max_features': 'auto', ...       0.746850
# 51  {'criterion': 'entropy', 'max_features': 'auto...       0.746678
# 37  {'criterion': 'entropy', 'max_features': 8, 'n...       0.745897
# 16  {'criterion': 'gini', 'max_features': 12, 'n_e...       0.744229
# 9   {'criterion': 'gini', 'max_features': 8, 'n_es...       0.742070
# 50  {'criterion': 'entropy', 'max_features': 'auto...       0.730894
# 29  {'criterion': 'entropy', 'max_features': 4, 'n...       0.730064
# 43  {'criterion': 'entropy', 'max_features': 12, '...       0.729426
# 36  {'criterion': 'entropy', 'max_features': 8, 'n...       0.727659
# 15  {'criterion': 'gini', 'max_features': 12, 'n_e...       0.727575
# 22  {'criterion': 'gini', 'max_features': 'auto', ...       0.727511
# 1   {'criterion': 'gini', 'max_features': 4, 'n_es...       0.726947
# 8   {'criterion': 'gini', 'max_features': 8, 'n_es...       0.725558
# 42  {'criterion': 'entropy', 'max_features': 12, '...       0.707422
# 49  {'criterion': 'entropy', 'max_features': 'auto...       0.703317
# 7   {'criterion': 'gini', 'max_features': 8, 'n_es...       0.703177
# 35  {'criterion': 'entropy', 'max_features': 8, 'n...       0.701276
# 28  {'criterion': 'entropy', 'max_features': 4, 'n...       0.701114
# 0   {'criterion': 'gini', 'max_features': 4, 'n_es...       0.700954
# 14  {'criterion': 'gini', 'max_features': 12, 'n_e...       0.698906
# 21  {'criterion': 'gini', 'max_features': 'auto', ...       0.697325
#
#     std_test_AUC  mean_test_Accuracy  std_test_Accuracy
# 34      0.003907            0.649984           0.004424
# 5       0.004801            0.649230           0.002711
# 55      0.005829            0.652867           0.003792
# 54      0.005667            0.654104           0.004651
# 27      0.004693            0.649676           0.005133
# 33      0.005753            0.651784           0.001827
# 6       0.004363            0.646641           0.004579
# 26      0.006683            0.649912           0.003237
# 40      0.005406            0.656907           0.004075
# 53      0.005620            0.652280           0.003207
# 41      0.006048            0.655929           0.003916
# 48      0.007107            0.654771           0.005203
# 32      0.006393            0.652764           0.002687
# 47      0.005183            0.655784           0.003694
# 12      0.006846            0.650487           0.003396
# 4       0.002862            0.646739           0.001465
# 13      0.005352            0.650994           0.002707
# 20      0.005452            0.651200           0.004017
# 31      0.007433            0.647803           0.004327
# 25      0.006849            0.645487           0.004481
# 19      0.004974            0.650967           0.003586
# 39      0.006393            0.655041           0.002360
# 11      0.006864            0.650814           0.003193
# 46      0.004890            0.653823           0.004248
# 52      0.003940            0.650373           0.004425
# 24      0.006004            0.645317           0.006517
# 3       0.005152            0.640571           0.003720
# 38      0.005090            0.651427           0.004299
# 18      0.006173            0.650487           0.004522
# 45      0.006639            0.652788           0.007007
# 10      0.005767            0.647052           0.004628
# 17      0.006085            0.646617           0.001518
# 30      0.007250            0.635433           0.003483
# 2       0.008361            0.635315           0.005056
# 44      0.006894            0.646142           0.004581
# 23      0.003224            0.637699           0.001923
# 51      0.002502            0.640330           0.002959
# 37      0.004241            0.645722           0.004086
# 16      0.004689            0.638960           0.003820
# 9       0.002668            0.636702           0.002868
# 50      0.006633            0.629496           0.002340
# 29      0.004980            0.621710           0.009168
# 43      0.008477            0.634318           0.005550
# 36      0.005168            0.639293           0.001490
# 15      0.011512            0.630212           0.003012
# 22      0.005708            0.626614           0.001786
# 1       0.005379            0.626112           0.005310
# 8       0.007194            0.628260           0.006225
# 42      0.004276            0.642322           0.005538
# 49      0.001701            0.637833           0.003878
# 7       0.006874            0.638823           0.003982
# 35      0.003915            0.636015           0.002566
# 28      0.005166            0.634828           0.003353
# 0       0.001018            0.628354           0.000864
# 14      0.007646            0.634702           0.004243
# 21      0.000605            0.631518           0.001127
