# %%
import joblib
import pandas as pd

# %%
result=joblib.load('gs_rf.pkl')

# %%
resultado=pd.DataFrame(result.cv_results_)

# %%
resultado.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_criterion', 'param_max_features', 'param_n_estimators', 'params',
#        'split0_test_AUC', 'split1_test_AUC', 'split2_test_AUC',
#        'split3_test_AUC', 'split4_test_AUC', 'mean_test_AUC', 'std_test_AUC',
#        'rank_test_AUC', 'split0_train_AUC', 'split1_train_AUC',
#        'split2_train_AUC', 'split3_train_AUC', 'split4_train_AUC',
#        'mean_train_AUC', 'std_train_AUC', 'split0_test_Accuracy',
#        'split1_test_Accuracy', 'split2_test_Accuracy', 'split3_test_Accuracy',
#        'split4_test_Accuracy', 'mean_test_Accuracy', 'std_test_Accuracy',
#        'rank_test_Accuracy', 'split0_train_Accuracy', 'split1_train_Accuracy',
#        'split2_train_Accuracy', 'split3_train_Accuracy',
#        'split4_train_Accuracy', 'mean_train_Accuracy', 'std_train_Accuracy'],
#       dtype='object')

# %%
resultado[['params','mean_test_AUC','std_test_AUC','mean_test_Accuracy','std_test_Accuracy']].sort_values(['mean_test_AUC'], ascending=[False])
# Out:
#                                                params  mean_test_AUC  \
# 55  {'criterion': 'entropy', 'max_features': 'auto...       0.768907
# 6   {'criterion': 'gini', 'max_features': 4, 'n_es...       0.768655
# 34  {'criterion': 'entropy', 'max_features': 4, 'n...       0.768509
# 33  {'criterion': 'entropy', 'max_features': 4, 'n...       0.768168
# 5   {'criterion': 'gini', 'max_features': 4, 'n_es...       0.768001
# 54  {'criterion': 'entropy', 'max_features': 'auto...       0.768001
# 27  {'criterion': 'gini', 'max_features': 'auto', ...       0.767852
# 40  {'criterion': 'entropy', 'max_features': 8, 'n...       0.767044
# 4   {'criterion': 'gini', 'max_features': 4, 'n_es...       0.766934
# 41  {'criterion': 'entropy', 'max_features': 8, 'n...       0.766547
# 25  {'criterion': 'gini', 'max_features': 'auto', ...       0.766408
# 26  {'criterion': 'gini', 'max_features': 'auto', ...       0.766334
# 48  {'criterion': 'entropy', 'max_features': 12, '...       0.765975
# 47  {'criterion': 'entropy', 'max_features': 12, '...       0.765698
# 20  {'criterion': 'gini', 'max_features': 12, 'n_e...       0.764942
# 12  {'criterion': 'gini', 'max_features': 8, 'n_es...       0.764791
# 13  {'criterion': 'gini', 'max_features': 8, 'n_es...       0.764430
# 19  {'criterion': 'gini', 'max_features': 12, 'n_e...       0.764068
# 32  {'criterion': 'entropy', 'max_features': 4, 'n...       0.763184
# 53  {'criterion': 'entropy', 'max_features': 'auto...       0.763093
# 39  {'criterion': 'entropy', 'max_features': 8, 'n...       0.762640
# 46  {'criterion': 'entropy', 'max_features': 12, '...       0.762126
# 11  {'criterion': 'gini', 'max_features': 8, 'n_es...       0.761818
# 52  {'criterion': 'entropy', 'max_features': 'auto...       0.760014
# 31  {'criterion': 'entropy', 'max_features': 4, 'n...       0.759971
# 18  {'criterion': 'gini', 'max_features': 12, 'n_e...       0.759698
# 45  {'criterion': 'entropy', 'max_features': 12, '...       0.759503
# 3   {'criterion': 'gini', 'max_features': 4, 'n_es...       0.758826
# 10  {'criterion': 'gini', 'max_features': 8, 'n_es...       0.758528
# 38  {'criterion': 'entropy', 'max_features': 8, 'n...       0.757547
# 24  {'criterion': 'gini', 'max_features': 'auto', ...       0.757523
# 17  {'criterion': 'gini', 'max_features': 12, 'n_e...       0.754007
# 30  {'criterion': 'entropy', 'max_features': 4, 'n...       0.748294
# 2   {'criterion': 'gini', 'max_features': 4, 'n_es...       0.747716
# 37  {'criterion': 'entropy', 'max_features': 8, 'n...       0.747289
# 23  {'criterion': 'gini', 'max_features': 'auto', ...       0.746841
# 9   {'criterion': 'gini', 'max_features': 8, 'n_es...       0.744572
# 51  {'criterion': 'entropy', 'max_features': 'auto...       0.743072
# 44  {'criterion': 'entropy', 'max_features': 12, '...       0.742532
# 16  {'criterion': 'gini', 'max_features': 12, 'n_e...       0.739784
# 29  {'criterion': 'entropy', 'max_features': 4, 'n...       0.731356
# 50  {'criterion': 'entropy', 'max_features': 'auto...       0.729511
# 36  {'criterion': 'entropy', 'max_features': 8, 'n...       0.728948
# 43  {'criterion': 'entropy', 'max_features': 12, '...       0.728628
# 8   {'criterion': 'gini', 'max_features': 8, 'n_es...       0.728091
# 22  {'criterion': 'gini', 'max_features': 'auto', ...       0.728040
# 1   {'criterion': 'gini', 'max_features': 4, 'n_es...       0.725705
# 15  {'criterion': 'gini', 'max_features': 12, 'n_e...       0.724912
# 42  {'criterion': 'entropy', 'max_features': 12, '...       0.708949
# 35  {'criterion': 'entropy', 'max_features': 8, 'n...       0.701939
# 7   {'criterion': 'gini', 'max_features': 8, 'n_es...       0.701522
# 14  {'criterion': 'gini', 'max_features': 12, 'n_e...       0.698689
# 0   {'criterion': 'gini', 'max_features': 4, 'n_es...       0.698530
# 49  {'criterion': 'entropy', 'max_features': 'auto...       0.697764
# 21  {'criterion': 'gini', 'max_features': 'auto', ...       0.697686
# 28  {'criterion': 'entropy', 'max_features': 4, 'n...       0.697215
#
#     std_test_AUC  mean_test_Accuracy  std_test_Accuracy
# 55      0.006636            0.815083           0.004139
# 6       0.005212            0.815333           0.004954
# 34      0.004999            0.813917           0.004595
# 33      0.005555            0.814625           0.003303
# 5       0.005238            0.814500           0.003956
# 54      0.005690            0.816083           0.004138
# 27      0.006143            0.815333           0.003153
# 40      0.006608            0.815583           0.003049
# 4       0.005912            0.813917           0.003202
# 41      0.005323            0.817042           0.002442
# 25      0.003717            0.814250           0.004678
# 26      0.006348            0.813208           0.003670
# 48      0.006573            0.816792           0.004458
# 47      0.007161            0.816083           0.003150
# 20      0.004606            0.816000           0.002873
# 12      0.007104            0.815958           0.004381
# 13      0.006071            0.816167           0.003542
# 19      0.005284            0.816042           0.003129
# 32      0.004912            0.814042           0.004082
# 53      0.005414            0.815667           0.003040
# 39      0.006557            0.816042           0.004093
# 46      0.007224            0.816542           0.003978
# 11      0.006610            0.814667           0.003818
# 52      0.007497            0.813667           0.003397
# 31      0.007291            0.814958           0.004225
# 18      0.006820            0.815250           0.003253
# 45      0.004786            0.814250           0.002111
# 3       0.006017            0.811292           0.005456
# 10      0.007108            0.814458           0.003256
# 38      0.005137            0.815167           0.003885
# 24      0.005301            0.813917           0.005454
# 17      0.005032            0.814000           0.003602
# 30      0.006824            0.809625           0.004775
# 2       0.008748            0.808417           0.003089
# 37      0.006913            0.811958           0.004088
# 23      0.004543            0.808083           0.003887
# 9       0.003488            0.810625           0.003731
# 51      0.007781            0.810375           0.004620
# 44      0.007021            0.813000           0.002718
# 16      0.003919            0.811042           0.004131
# 29      0.008132            0.805167           0.004221
# 50      0.003867            0.806375           0.003298
# 36      0.006467            0.808333           0.002804
# 43      0.005385            0.806208           0.003424
# 8       0.008597            0.809208           0.002879
# 22      0.006611            0.806167           0.003542
# 1       0.006525            0.806375           0.004471
# 15      0.002568            0.806583           0.004436
# 42      0.004562            0.794000           0.004190
# 35      0.009000            0.793708           0.005444
# 7       0.011631            0.792833           0.004333
# 14      0.002678            0.792458           0.004735
# 0       0.008264            0.788083           0.005236
# 49      0.006428            0.791667           0.004951
# 21      0.003907            0.789875           0.001212
# 28      0.004127            0.789167           0.007271
