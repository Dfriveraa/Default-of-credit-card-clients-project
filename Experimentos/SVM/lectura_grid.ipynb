# %%
import joblib
import pandas as pd

# %%
result=joblib.load('gs_svm.pkl')

# %%
resultado=pd.DataFrame(result.cv_results_)

# %%
resultado[['params','mean_test_AUC','std_test_AUC','mean_test_Accuracy','std_test_Accuracy']].sort_values(['mean_test_AUC'], ascending=[False])
# Out:
#                                               params  mean_test_AUC  \
# 18        {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}       0.767202
# 26          {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}       0.765331
# 16       {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}       0.765285
# 32        {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}       0.764906
# 24         {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}       0.764305
# 10       {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}       0.760817
# 34         {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}       0.758294
# 8       {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}       0.757046
# 0      {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}       0.756672
# 9    {'C': 0.01, 'gamma': 0.001, 'kernel': 'linear'}       0.755109
# 11    {'C': 0.01, 'gamma': 0.01, 'kernel': 'linear'}       0.755109
# 13     {'C': 0.01, 'gamma': 0.1, 'kernel': 'linear'}       0.755109
# 15       {'C': 0.01, 'gamma': 1, 'kernel': 'linear'}       0.755109
# 7       {'C': 0.001, 'gamma': 1, 'kernel': 'linear'}       0.755109
# 1   {'C': 0.001, 'gamma': 0.001, 'kernel': 'linear'}       0.755109
# 5     {'C': 0.001, 'gamma': 0.1, 'kernel': 'linear'}       0.755109
# 3    {'C': 0.001, 'gamma': 0.01, 'kernel': 'linear'}       0.755109
# 33     {'C': 10, 'gamma': 0.001, 'kernel': 'linear'}       0.750549
# 35      {'C': 10, 'gamma': 0.01, 'kernel': 'linear'}       0.750549
# 37       {'C': 10, 'gamma': 0.1, 'kernel': 'linear'}       0.750549
# 39         {'C': 10, 'gamma': 1, 'kernel': 'linear'}       0.750549
# 20         {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}       0.748335
# 19     {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}       0.748335
# 17    {'C': 0.1, 'gamma': 0.001, 'kernel': 'linear'}       0.748335
# 21      {'C': 0.1, 'gamma': 0.1, 'kernel': 'linear'}       0.748335
# 23        {'C': 0.1, 'gamma': 1, 'kernel': 'linear'}       0.748335
# 25      {'C': 1, 'gamma': 0.001, 'kernel': 'linear'}       0.746411
# 27       {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}       0.746411
# 29        {'C': 1, 'gamma': 0.1, 'kernel': 'linear'}       0.746411
# 31          {'C': 1, 'gamma': 1, 'kernel': 'linear'}       0.746411
# 2       {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'}       0.744130
# 28           {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}       0.740787
# 12        {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}       0.722989
# 36          {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}       0.706037
# 4        {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}       0.705270
# 22           {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}       0.683792
# 14          {'C': 0.01, 'gamma': 1, 'kernel': 'rbf'}       0.683689
# 6          {'C': 0.001, 'gamma': 1, 'kernel': 'rbf'}       0.683687
# 30             {'C': 1, 'gamma': 1, 'kernel': 'rbf'}       0.661213
# 38            {'C': 10, 'gamma': 1, 'kernel': 'rbf'}       0.632102
#
#     std_test_AUC  mean_test_Accuracy  std_test_Accuracy
# 18      0.002979            0.695905           0.003001
# 26      0.004086            0.702122           0.004448
# 16      0.000732            0.686918           0.003499
# 32      0.004240            0.700475           0.005317
# 24      0.004710            0.688200           0.003924
# 10      0.001036            0.682175           0.002814
# 34      0.005265            0.701536           0.005667
# 8       0.001021            0.590236           0.006007
# 0       0.000578            0.500000           0.000000
# 9       0.003777            0.691154           0.007865
# 11      0.003777            0.691154           0.007865
# 13      0.003777            0.691154           0.007865
# 15      0.003777            0.691154           0.007865
# 7       0.003819            0.685174           0.004065
# 1       0.003819            0.685174           0.004065
# 5       0.003819            0.685174           0.004065
# 3       0.003819            0.685174           0.004065
# 33      0.000158            0.687190           0.002458
# 35      0.000158            0.687190           0.002458
# 37      0.000158            0.687190           0.002458
# 39      0.000158            0.687190           0.002458
# 20      0.005333            0.688714           0.003767
# 19      0.007825            0.690244           0.006467
# 17      0.007825            0.690244           0.006467
# 21      0.007825            0.690244           0.006467
# 23      0.007825            0.690244           0.006467
# 25      0.003044            0.687004           0.006256
# 27      0.003044            0.687004           0.006256
# 29      0.003044            0.687004           0.006256
# 31      0.003044            0.687004           0.006256
# 2       0.002136            0.544582           0.018932
# 28      0.007401            0.689994           0.002223
# 12      0.003505            0.661204           0.000315
# 36      0.002244            0.651384           0.003533
# 4       0.001847            0.500000           0.000000
# 22      0.005542            0.583954           0.002457
# 14      0.004330            0.500000           0.000000
# 6       0.004330            0.500000           0.000000
# 30      0.005272            0.567453           0.004762
# 38      0.005807            0.549427           0.001512
