# %%
import joblib
import pandas as pd

# %%
result=joblib.load('gs_discriminante.pkl')

# %%
resultado=pd.DataFrame(result.cv_results_)

# %%
resultado.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_reg_param', 'param_store_covariance', 'param_tol', 'params',
#        'split0_test_AUC', 'split1_test_AUC', 'split2_test_AUC',
#        'split3_test_AUC', 'split4_test_AUC', 'split5_test_AUC',
#        'split6_test_AUC', 'split7_test_AUC', 'split8_test_AUC',
#        'split9_test_AUC', 'mean_test_AUC', 'std_test_AUC', 'rank_test_AUC',
#        'split0_train_AUC', 'split1_train_AUC', 'split2_train_AUC',
#        'split3_train_AUC', 'split4_train_AUC', 'split5_train_AUC',
#        'split6_train_AUC', 'split7_train_AUC', 'split8_train_AUC',
#        'split9_train_AUC', 'mean_train_AUC', 'std_train_AUC',
#        'split0_test_Accuracy', 'split1_test_Accuracy', 'split2_test_Accuracy',
#        'split3_test_Accuracy', 'split4_test_Accuracy', 'split5_test_Accuracy',
#        'split6_test_Accuracy', 'split7_test_Accuracy', 'split8_test_Accuracy',
#        'split9_test_Accuracy', 'mean_test_Accuracy', 'std_test_Accuracy',
#        'rank_test_Accuracy', 'split0_train_Accuracy', 'split1_train_Accuracy',
#        'split2_train_Accuracy', 'split3_train_Accuracy',
#        'split4_train_Accuracy', 'split5_train_Accuracy',
#        'split6_train_Accuracy', 'split7_train_Accuracy',
#        'split8_train_Accuracy', 'split9_train_Accuracy', 'mean_train_Accuracy',
#        'std_train_Accuracy'],
#       dtype='object')

# %%
resultado[['params','mean_test_AUC','std_test_AUC','mean_test_Accuracy','std_test_Accuracy']].sort_values(['mean_test_AUC'], ascending=[False])
# Out:
#                                                params  mean_test_AUC  \
# 39  {'reg_param': 0.1, 'store_covariance': False, ...       0.744082
# 38  {'reg_param': 0.1, 'store_covariance': False, ...       0.744082
# 37  {'reg_param': 0.1, 'store_covariance': False, ...       0.744082
# 36  {'reg_param': 0.1, 'store_covariance': False, ...       0.744082
# 35  {'reg_param': 0.1, 'store_covariance': True, '...       0.744082
# 34  {'reg_param': 0.1, 'store_covariance': True, '...       0.744082
# 33  {'reg_param': 0.1, 'store_covariance': True, '...       0.744082
# 32  {'reg_param': 0.1, 'store_covariance': True, '...       0.744082
# 27  {'reg_param': 0.01, 'store_covariance': True, ...       0.739854
# 24  {'reg_param': 0.01, 'store_covariance': True, ...       0.739854
# 25  {'reg_param': 0.01, 'store_covariance': True, ...       0.739854
# 26  {'reg_param': 0.01, 'store_covariance': True, ...       0.739854
# 31  {'reg_param': 0.01, 'store_covariance': False,...       0.739854
# 28  {'reg_param': 0.01, 'store_covariance': False,...       0.739854
# 29  {'reg_param': 0.01, 'store_covariance': False,...       0.739854
# 30  {'reg_param': 0.01, 'store_covariance': False,...       0.739854
# 21  {'reg_param': 0.001, 'store_covariance': False...       0.738084
# 23  {'reg_param': 0.001, 'store_covariance': False...       0.738084
# 22  {'reg_param': 0.001, 'store_covariance': False...       0.738084
# 20  {'reg_param': 0.001, 'store_covariance': False...       0.738084
# 18  {'reg_param': 0.001, 'store_covariance': True,...       0.738084
# 17  {'reg_param': 0.001, 'store_covariance': True,...       0.738084
# 16  {'reg_param': 0.001, 'store_covariance': True,...       0.738084
# 19  {'reg_param': 0.001, 'store_covariance': True,...       0.738084
# 10  {'reg_param': 0.0001, 'store_covariance': True...       0.737846
# 15  {'reg_param': 0.0001, 'store_covariance': Fals...       0.737846
# 14  {'reg_param': 0.0001, 'store_covariance': Fals...       0.737846
# 13  {'reg_param': 0.0001, 'store_covariance': Fals...       0.737846
# 12  {'reg_param': 0.0001, 'store_covariance': Fals...       0.737846
# 11  {'reg_param': 0.0001, 'store_covariance': True...       0.737846
# 9   {'reg_param': 0.0001, 'store_covariance': True...       0.737846
# 8   {'reg_param': 0.0001, 'store_covariance': True...       0.737846
# 4   {'reg_param': 1e-05, 'store_covariance': False...       0.737825
# 2   {'reg_param': 1e-05, 'store_covariance': True,...       0.737825
# 3   {'reg_param': 1e-05, 'store_covariance': True,...       0.737825
# 1   {'reg_param': 1e-05, 'store_covariance': True,...       0.737825
# 5   {'reg_param': 1e-05, 'store_covariance': False...       0.737825
# 6   {'reg_param': 1e-05, 'store_covariance': False...       0.737825
# 7   {'reg_param': 1e-05, 'store_covariance': False...       0.737825
# 0   {'reg_param': 1e-05, 'store_covariance': True,...       0.737825
#
#     std_test_AUC  mean_test_Accuracy  std_test_Accuracy
# 39      0.011765            0.739125           0.009410
# 38      0.011765            0.739125           0.009410
# 37      0.011765            0.739125           0.009410
# 36      0.011765            0.739125           0.009410
# 35      0.011765            0.739125           0.009410
# 34      0.011765            0.739125           0.009410
# 33      0.011765            0.739125           0.009410
# 32      0.011765            0.739125           0.009410
# 27      0.012203            0.702375           0.025180
# 24      0.012203            0.702375           0.025180
# 25      0.012203            0.702375           0.025180
# 26      0.012203            0.702375           0.025180
# 31      0.012203            0.702375           0.025180
# 28      0.012203            0.702375           0.025180
# 29      0.012203            0.702375           0.025180
# 30      0.012203            0.702375           0.025180
# 21      0.012916            0.675375           0.037284
# 23      0.012916            0.675375           0.037284
# 22      0.012916            0.675375           0.037284
# 20      0.012916            0.675375           0.037284
# 18      0.012916            0.675375           0.037284
# 17      0.012916            0.675375           0.037284
# 16      0.012916            0.675375           0.037284
# 19      0.012916            0.675375           0.037284
# 10      0.012918            0.670875           0.038652
# 15      0.012918            0.670875           0.038652
# 14      0.012918            0.670875           0.038652
# 13      0.012918            0.670875           0.038652
# 12      0.012918            0.670875           0.038652
# 11      0.012918            0.670875           0.038652
# 9       0.012918            0.670875           0.038652
# 8       0.012918            0.670875           0.038652
# 4       0.012906            0.670417           0.038636
# 2       0.012906            0.670417           0.038636
# 3       0.012906            0.670417           0.038636
# 1       0.012906            0.670417           0.038636
# 5       0.012906            0.670417           0.038636
# 6       0.012906            0.670417           0.038636
# 7       0.012906            0.670417           0.038636
# 0       0.012906            0.670417           0.038636
