# %%
import joblib
import pandas as pd

# %%
result=joblib.load('gs_rna.pkl')

# %%
resultado=pd.DataFrame(result.cv_results_)

# %%
resultado.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_activation', 'param_alpha', 'param_hidden_layer_sizes',
#        'param_max_iter', 'param_solver', 'params', 'split0_test_AUC',
#        'split1_test_AUC', 'mean_test_AUC', 'std_test_AUC', 'rank_test_AUC',
#        'split0_train_AUC', 'split1_train_AUC', 'mean_train_AUC',
#        'std_train_AUC', 'split0_test_Accuracy', 'split1_test_Accuracy',
#        'mean_test_Accuracy', 'std_test_Accuracy', 'rank_test_Accuracy',
#        'split0_train_Accuracy', 'split1_train_Accuracy', 'mean_train_Accuracy',
#        'std_train_Accuracy'],
#       dtype='object')

# %%
resultado[['params','mean_test_AUC','std_test_AUC','mean_test_Accuracy','std_test_Accuracy']].sort_values(['mean_test_AUC'], ascending=[False])
# Out:
#                                                params  mean_test_AUC  \
# 47  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.775941
# 40  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.775756
# 32  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.774783
# 37  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.774519
# 30  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.773558
# 31  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.773028
# 48  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.772143
# 34  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.771797
# 51  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.771738
# 20  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.771559
# 42  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.771381
# 45  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.771308
# 41  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.771037
# 29  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.770494
# 27  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.770388
# 36  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.770380
# 44  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.769770
# 10  {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.769592
# 43  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.769420
# 18  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.769266
# 46  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.769114
# 13  {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.769054
# 9   {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.768944
# 33  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.768942
# 35  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.768806
# 23  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.768795
# 11  {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.768744
# 14  {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.768626
# 38  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.768545
# 15  {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.768514
# 53  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.768460
# 26  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.768381
# 5   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.768327
# 21  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.768045
# 52  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.767738
# 12  {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.767269
# 24  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.767000
# 50  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.766920
# 25  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.766824
# 28  {'activation': 'tanh', 'alpha': 0.1, 'hidden_l...       0.766822
# 22  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.766789
# 7   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.766752
# 0   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.766721
# 2   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.766505
# 1   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.766477
# 17  {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.766190
# 4   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.765866
# 19  {'activation': 'logistic', 'alpha': 0.001, 'hi...       0.765602
# 8   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.765307
# 6   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.764824
# 3   {'activation': 'logistic', 'alpha': 0.1, 'hidd...       0.764569
# 39  {'activation': 'tanh', 'alpha': 0.01, 'hidden_...       0.762884
# 16  {'activation': 'logistic', 'alpha': 0.01, 'hid...       0.761787
# 49  {'activation': 'tanh', 'alpha': 0.001, 'hidden...       0.761266
#
#     std_test_AUC  mean_test_Accuracy  std_test_Accuracy
# 47      0.000435            0.665266           0.002405
# 40      0.000735            0.663162           0.001486
# 32      0.000875            0.666210           0.003262
# 37      0.000503            0.649834           0.006606
# 30      0.000763            0.659701           0.002219
# 31      0.000145            0.663222           0.003561
# 48      0.001360            0.664506           0.001485
# 34      0.000239            0.662137           0.003048
# 51      0.002921            0.656182           0.000646
# 20      0.000138            0.660351           0.006606
# 42      0.003397            0.664478           0.003582
# 45      0.001025            0.664044           0.002488
# 41      0.001642            0.662066           0.005708
# 29      0.000792            0.661372           0.000015
# 27      0.000966            0.656821           0.002007
# 36      0.003824            0.658837           0.001038
# 44      0.006172            0.658037           0.004407
# 10      0.000788            0.656280           0.005979
# 43      0.002488            0.657479           0.005499
# 18      0.000370            0.659050           0.000110
# 46      0.002180            0.668540           0.001980
# 13      0.001571            0.660374           0.010665
# 9       0.001410            0.655322           0.005540
# 33      0.002478            0.667430           0.002503
# 35      0.006305            0.651887           0.002034
# 23      0.002082            0.658105           0.002961
# 11      0.000629            0.661156           0.000522
# 14      0.001379            0.656069           0.005934
# 38      0.003339            0.665251           0.000950
# 15      0.000279            0.661164           0.003576
# 53      0.003957            0.655418           0.000498
# 26      0.001816            0.658152           0.008308
# 5       0.000426            0.657155           0.003333
# 21      0.000931            0.653877           0.004567
# 52      0.002988            0.649347           0.009040
# 12      0.000717            0.653399           0.000322
# 24      0.003034            0.665882           0.000288
# 50      0.006406            0.660387           0.007319
# 25      0.001047            0.654729           0.017937
# 28      0.004118            0.663258           0.007122
# 22      0.001032            0.644837           0.004464
# 7       0.001570            0.642143           0.001157
# 0       0.000157            0.651300           0.000024
# 2       0.001213            0.648538           0.004505
# 1       0.000039            0.646061           0.003080
# 17      0.000401            0.651988           0.009447
# 4       0.000733            0.652094           0.001468
# 19      0.002362            0.643183           0.011479
# 8       0.000597            0.655099           0.003337
# 6       0.000138            0.656603           0.006113
# 3       0.000200            0.638615           0.010851
# 39      0.001117            0.661857           0.000110
# 16      0.005430            0.626954           0.026924
# 49      0.004313            0.655262           0.005094
